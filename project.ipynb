# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
print(ds.head(5))
# Out:
#    Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0           1       153771986  False            ferrari 57 inmobiliaria
# 1           2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           3       153430440  False                 look find boadilla
# 3           4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           5       153180188  False            ferrari 57 inmobiliaria
#
#    phone_realEstate                                       url_inmueble  rooms  \
# 0       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 1       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 2       916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
# 3       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 4       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
# TODO
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
y = df.loc[df.price == df.price.max(), 'address'].to_list()[0]
x = (df['price'].max())
print('The house located in', y , 'is the most expensive and its price is', x)
# Out:
# The house located in El Escorial is the most expensive and its price is 8500000

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
y = df.loc[df.price == df.price.min(), 'address'].to_list()[0]
x = (df['price'].min())
print('The house located in', y , 'is the cheapest and its price is', x)
# Out:
# The house located in Parla is the cheapest and its price is 0

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
y = df.loc[df.surface == df.surface.max(), 'address'].to_list()[0]
x = (df['surface'].max())
print('The biggest house is located in', y , 'and its surface is', x, 'meters')

yy = df.loc[df.surface == df.surface.min(), 'address'].to_list()[0]
xx = (df['surface'].min())
print('The smallest house is located in', yy , 'and its surface is', xx, 'meters')
# Out:
# The biggest house is located in Sevilla la Nueva and its surface is 249000.0 meters
# The smallest house is located in Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
# TODO
import numpy as np
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
a = len(df) - df['level5'].count()
b = df['level5'].tolist()
c = len(df["address"])
unique_values = pd.unique(df['level5'])
unique_values_str = ', '.join(unique_values)
print('The number of populations is', c)
print (unique_values_str)
# Out:
# The number of populations is 15335
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
# TODO
import pandas as pd
import numpy as np

# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
print(df.any(axis=1))
print(df.any(axis='rows'))
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 15330    True
# 15331    True
# 15332    True
# 15333    True
# 15334    True
# Length: 15335, dtype: bool
# Unnamed: 0           True
# id_realEstates       True
# isNew                True
# realEstate_name      True
# phone_realEstate     True
# url_inmueble         True
# rooms                True
# bathrooms            True
# surface              True
# price                True
# date                 True
# description          True
# address              True
# country              True
# level1               True
# level2               True
# level3               True
# level4               True
# level5               True
# level6               True
# level7               True
# level8               True
# upperLevel           True
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
a = df.shape
print('The dimension of the original dataframe is', df.shape)

df_cleaned = df.dropna()
print('The dimension of the cleaned dataframe is', df_cleaned.shape)
# Out:
# The dimension of the original dataframe is (15335, 37)
# The dimension of the cleaned dataframe is (0, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
y = df.loc[df.level5 == 'Arroyomolinos (Madrid)', 'price'].values
mean_price = np.mean(y)
print("Mean price in Arroyomolinos (Madrid):", mean_price)
# Out:
# Mean price in Arroyomolinos (Madrid): 294541.59854014596

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code
import matplotlib.pyplot as plt

# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
y = df.loc[df.level5 == 'Arroyomolinos (Madrid)', 'price'].values

plt.figure(figsize = (15, 4))
plt.hist(y, bins = 100, alpha = 0.9)
plt.xlabel('PRICES')
plt.ylabel('numero de propiedades')
plt.title("PRICE RANGE IN ARROYOMOLINOS")
plt.show()

# %% [markdown]
# The prices in Arroyomolinos range mostly betwwen 180000 and 400000 with a grear number ofo properties around 280000. An important number of property prices is located in the 320-400k interval. There are very few outliers on both extremes of fo the range.

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 09. Are the averages of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')

y = df.loc[df.level5 == 'Valdemorillo', 'price'].values
average_val = np.mean(y)
round_val = np.round(average_val, decimals=2)
print('The average value in Valdemorillo is', round_val)

df = pd.read_csv('assets/real_estate.csv', sep=';')
y = df.loc[df.level5 == 'Galapagar', 'price'].values
average_val2 = np.mean(y)
round_val2 = np.round(average_val2, decimals=2)
print('The average value in Galapagar is', round_val2)
print('The difference betwwen both values is', round_val - round_val2,)
# Out:
# The average value in Valdemorillo is 363860.29
# The average value in Galapagar is 360063.2
# The difference betwwen both values is 3797.0899999999674

# %% [markdown]
# #### Exercise 10. Are the averages of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')

df['pps'] = df['price'] / df['surface']
#print(df['pps'])

y = df.loc[df.level5 == 'Valdemorillo', 'pps']
average_pps = np.mean(y)
print('The average price per square meter in Valdemorillo is', average_pps)

x = df.loc[df.level5 == 'Galapagar', 'pps']
average_pps2 = np.mean(x)
print('The average price per square meter in Galapagar is',average_pps2)
# Out:
# The average price per square meter in Valdemorillo is 1317.9502109024986
# The average price per square meter in Galapagar is 1606.3240303094024

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
# TODO: Code
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')

newdata = df.loc[(df['surface']>0) & (df['surface']< 10000)]

plt.scatter(newdata['surface'], newdata['price'])

# Add labels and title
plt.xlabel('new_data')
plt.ylabel('y')
plt.title('Scatter Plot')

# Show plot
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')

column_names_list = df.columns.tolist()
#print(column_names_list)

unique_values = df['realEstate_name'].unique()
print('The number of populations is', len(unique_values))
# Out:
# The number of populations is 1822

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')

#unique_values = df['level5'].unique()
#print(len(unique_values))

value_counts = df['level5'].value_counts()

highest_occurrence_pop = df['level5'].value_counts().idxmax()
highest_occurrence = df['level5'].value_counts().max()

print('The populations with the biggest number of houses is', highest_occurrence_pop , 'with',  highest_occurrence, 'houses')
# Out:
# The populations with the biggest number of houses is  Madrid Capital with 6643 houses

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')

south_df = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]

filtered_df = df[df['level5'].isin(south_df)]
print(filtered_df.shape)
print(filtered_df)
# Out:
# (907, 37)
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
# TODO: Code
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')

south_df = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]
filtered_df = df[df['level5'].isin(south_df)]

median_values = filtered_df.groupby('level5')['price'].median()
print(median_values)

plt.figure(figsize = (15, 4))
plt.bar(median_values.index,median_values)
plt.xlabel('MEDIAN VALUES')
plt.ylabel('populations')
#plt.title("PRICE RANGE IN ARROYOMOLINOS")
plt.show()
# Out:
# level5
# Alcorcón       179500.0
# Fuenlabrada    155000.0
# Getafe         285305.0
# Leganés        169950.0
# Name: price, dtype: float64

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')

south_df = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]
filtered_df = df[df['level5'].isin(south_df)]

priceM = filtered_df.price.mean()
priceV = filtered_df.price.var()
print('Price mean and variance', priceM, priceV)

SurM = filtered_df.surface.mean()
SurV = filtered_df.surface.var()
print('Surface mean and variance', SurM, SurV)

batM = filtered_df.bathrooms.mean()
batV = filtered_df.bathrooms.var()
print('Bathroom mean and variance', batM, batV)

roomM = filtered_df.rooms.mean()
roomV = filtered_df.rooms.var()
print('Rooms mean and variance', roomM, roomV)
# Out:
# Price mean and variance 223094.48070562293 14921367508.04902
# Surface mean and variance 111.75222363405337 4263.051760316337
# Bathroom mean and variance 1.633221850613155 0.5717968625577321
# Rooms mean and variance 3.0177383592017737 0.7188858892927542
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 24
#      21 roomV = filtered_df.rooms.var()
#      22 print('Rooms mean and variance', roomM, roomV)
# ---> 24 print(south_df.head())
#
# AttributeError: 'list' object has no attribute 'head'

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# TODO
# this CSV file contains semicolons instead of comas as separator
df = pd.read_csv('assets/real_estate.csv', sep=';')
south_df = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]
f_df = df[df['level5'].isin(south_df)]

max_by_category = f_df.groupby(['level5'])['price'].max()
print(max_by_category)
# Out:
# level5
# Alcorcón        950000
# Fuenlabrada     490000
# Getafe         1050000
# Leganés         650000
# Name: price, dtype: int64

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# TODO
import matplotlib.pyplot as plt 
import pandas as pd


df = pd.read_csv('assets/real_estate.csv', sep=';')
south_df = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]
filtered_df = df[df['level5'].isin(south_df)]

fig, axs = plt.subplots(len(south_df), 1, figsize=(8, 6 * len(south_df)))

for i, location in enumerate(south_df):
    filtered_df = df[df['level5'] == location]
    normalized_df = (filtered_df['price']-filtered_df['price'].min())/(filtered_df['price'].max()-filtered_df['price'].min())
    axs[i].hist(normalized_df, bins=30, color='skyblue', edgecolor='black')
    axs[i].set_xlabel('Price')
    axs[i].set_ylabel('Frequency')
    axs[i].set_title(f'Histogram for {location}')
    
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %% [markdown]
# El precio medio por metro cuadrado en Alcorcón es el mas alto de madrid, aunqur su desviacion standard es relativamernte baja. La desviacion standard dse Getafe is sorprendentemente alta

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle("Graficas de dispersion de Superficie contra precio segun municipio", fontsize=16)
for i, population in enumerate(populations):
    row = i // 2
    col = i % 2
    ax = axs[row, col]
    population_data = ds[ds['level5'] == population]
    ax.scatter(population_data['surface'], population_data['price'], alpha=0.5)
    ax.set_title(f"Population: {population}")
    ax.set_xlabel("Surface Area (sqm)")
    ax.set_ylabel("Price")
    ax.grid(True)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %% [markdown]
# Ni idea como hacer esto.

# %%
from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
